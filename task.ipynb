# %%
import pandas as pd
import numpy as np
# %pip install matplotlib
import matplotlib.pyplot as plt
df = pd.read_csv('D:\GB\Основы языка Python для аналитиков/kc-house-data (1).csv')
df.head()
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 23.3.2
# [notice] To update, run: C:\Users\Asus\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# ...

# %% [markdown]
# 1.2. Изучите стоимости недвижимости

# %%
plt.hist(df['price'])
plt.xlabel('USD')
plt.ylabel('count')
plt.title('стоимость недвижимости')
# Out:
# Text(0.5, 1.0, 'стоимость недвижимости')

# %% [markdown]
# Максимальное количество недвижимости продается по цене до ~700 000-1 000 000 usd

# %% [markdown]
# 1.3. Изучите распределение квадратуры жилой

# %%
plt.hist(df['sqft_living'])
plt.xlabel('кв м')
plt.ylabel('count')
plt.title('распределение жилой квадратуры')
# Out:
# Text(0.5, 1.0, 'распределение жилой квадратуры')

# %% [markdown]
# Максимальное количество недвижимости продается с жилой площадью от ~1700 до 2300 кв.м.

# %% [markdown]
# 1.4. Изучите распределение года постройки

# %%
data_yr = df['yr_built'].value_counts()
data_yr
# Out:
# yr_built
# 2014    559
# 2006    454
# 2005    450
# 2004    433
# 2003    422
#        ...
# 1933     30
# 1901     29
# 1902     27
# 1935     24
# 1934     21
# Name: count, Length: 116, dtype: int64

# %%
plt.hist(df['yr_built'])
plt.xlabel('год')
plt.ylabel('count')
plt.title('распределение года постройки')
# Out:
# Text(0.5, 1.0, 'распределение года постройки')

# %% [markdown]
# Наибольшее количество домов построены после 1950-го года

# %% [markdown]
# 2.1. Изучите распределение домов от наличия вида на набережную

# %%
data = df['waterfront'].value_counts()
data
# Out:
# waterfront
# 0    21450
# 1      163
# Name: count, dtype: int64

# %%
plt.pie(data.values, labels=data.index, autopct='%1.2f%%')
plt.legend(data.index)

# %% [markdown]
# Всего лишь 0,75% всей недвижимости продается с видом на набережную

# %% [markdown]
# 2.2. Изучите распределение этажей домов

# %%
data = df['floors'].value_counts()
data
# Out:
# floors
# 1.0    10680
# 2.0     8241
# 1.5     1910
# 3.0      613
# 2.5      161
# 3.5        8
# Name: count, dtype: int64

# %%
plt.bar(data.index, data.values)
# Out:
# <BarContainer object of 6 artists>

# %% [markdown]
# 1. Большая часть домов состоит из 1 и 2 этажей.
# 2. Одноэтажные дома пользуются наибольшим спросом
# 3. Минимальная доля продажи приходится на 2,5-этажные и 3,5-этажные дома

# %% [markdown]
# 2.3. Изучите распределение состояния домов

# %%
data = df['condition'].value_counts()
data
# Out:
# condition
# 3    14031
# 4     5679
# 5     1701
# 2      172
# 1       30
# Name: count, dtype: int64

# %%
plt.pie(data.values, labels=data.index, autopct='%1.2f%%')
plt.legend(data.index)

# %% [markdown]
# Менее 1% домов в плохом состоянии, около 2/3 домов в среднем (3) состоянии

# %% [markdown]
# Условие 3: 3 задача
# Исследуйте, какие характеристики недвижимости влияют на стоимость недвижимости, с применением не менее 5 диаграмм из урока.

# %%
# %pip install seaborn
import seaborn as sns
sns.boxplot(x=df['grade'], y=df['price'],showfliers = False)
plt.xlabel('Класс')
plt.ylabel('Цена')
plt.title('Распределение цен в зависимости от класса дома')
# Out:
# [notice] A new release of pip is available: 23.2.1 -> 23.3.2
# [notice] To update, run: C:\Users\Asus\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.Requirement already satisfied: seaborn in c:\users\asus\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (0.13.2)
# ...
# Text(0.5, 1.0, 'Распределение цен в зависимости от класса дома')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %%
df2 = df[['price','bedrooms','sqft_lot','floors','yr_built','grade']]
corr_matrix = np.round(df2.corr(),2)
corr_matrix
# Out:
#           price  bedrooms  sqft_lot  floors  yr_built  grade
# price      1.00      0.31      0.09    0.26      0.05   0.67
# bedrooms   0.31      1.00      0.03    0.18      0.15   0.36
# sqft_lot   0.09      0.03      1.00   -0.01      0.05   0.11
# floors     0.26      0.18     -0.01    1.00      0.49   0.46
# yr_built   0.05      0.15      0.05    0.49      1.00   0.45
# grade      0.67      0.36      0.11    0.46      0.45   1.00

# %%
sns.heatmap(corr_matrix,annot=True,linewidths=5,cmap='coolwarm')
# Out:
# <Axes: >

# %%
sns.jointplot(data=df, x="sqft_living15", y="price", kind="reg", height=12, ratio=4);

# %%
sns.jointplot(x = df['price'], y = df['grade'], kind = 'reg', height=12, ratio=4)

# %%
data = df.groupby('yr_built')['price'].mean().reset_index()
data
# Out:
#      yr_built          price
# 0        1900  581387.206897
# 1        1901  556935.931034
# 2        1902  673007.407407
# 3        1903  480958.195652
# 4        1904  583756.644444
# ..        ...            ...
# 111      2011  544522.000000
# 112      2012  527447.335294
# 113      2013  678545.452736
# 114      2014  683681.754919
# 115      2015  759785.157895
#
# [116 rows x 2 columns]

# %%
plt.figure(figsize=(15, 6))
plt.scatter(data['yr_built'], data['price'])
plt.title('Распределение средних цен в зависимости от года постройки')
# Out:
# Text(0.5, 1.0, 'Распределение средних цен в зависимости от года постройки')

# %%
plt.figure(figsize=(14, 10))

sns.boxplot(x=df['grade'], y=df['price'], whis=1.0)

plt.xlabel('Класс')
plt.ylabel('Цена')
plt.title('Распределение цен в зависимости от класса дома')
# Out:
# Text(0.5, 1.0, 'Распределение цен в зависимости от класса дома')

# %% [markdown]
# На цену недвижимости влияют больше всего следующие параметры:
# жилая площадь;
# класс;
# размеры 15 соседних домов;
# Реже продоют дома с 3,5 этажами.
